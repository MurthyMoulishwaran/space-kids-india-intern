# %%
from IPython.display import display
from PIL import Image

# %%
image1 = Image.open(r"C:\Users\Moulishwaran\OneDrive\Pictures\Screenshots\Screenshot 2025-03-08 123347.png")
image2 = Image.open(r"C:\Users\Moulishwaran\OneDrive\Pictures\Screenshots\Screenshot 2025-03-08 123434.png")
image3 = Image.open(r"C:\Users\Moulishwaran\OneDrive\Pictures\Screenshots\Screenshot 2025-03-08 123454.png")
image4 = Image.open(r"C:\Users\Moulishwaran\OneDrive\Pictures\Screenshots\Screenshot 2025-03-08 123513.png")
image5 = Image.open(r"C:\Users\Moulishwaran\OneDrive\Pictures\Screenshots\Screenshot 2025-03-08 123543.png")
image6 = Image.open(r"C:\Users\Moulishwaran\OneDrive\Pictures\Screenshots\Screenshot 2025-03-08 123602.png")

# %% [markdown]
# 1. streamlit fisrst output page

# %%
display(image1)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1919x990>

# %% [markdown]
# 2. Choose the image or pdf from disk

# %%
display(image2)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1919x964>

# %%
3. successfully load the file

# %%
display(image3)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1908x969>

# %%
4. search the extracted text

# %%
display(image4)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1919x968>

# %%
select the file

# %%
display(image5)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1911x980>

# %%
display(image6)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1917x985>
